# %%
# !pip install sentence-transformers

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
df = pd.read_csv('/content/drive/MyDrive/resume_project/resume_dataset_step2.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
resume_embeddings = model.encode(
    df["Resume_Text"].tolist(),
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/122 [00:00<?, ?it/s]

# %%
job_embeddings = model.encode(
    df["Job_Description"].tolist(),
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/122 [00:00<?, ?it/s]

# %%
print(resume_embeddings.shape)
print(job_embeddings.shape)
# Out:
# (3894, 384)
# (3894, 384)

# %%
import numpy as np

np.save("/content/drive/MyDrive/resume_project/resume_embeddings.npy", resume_embeddings)
np.save("/content/drive/MyDrive/resume_project/job_embeddings.npy", job_embeddings)
