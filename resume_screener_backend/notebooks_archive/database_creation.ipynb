# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 13.4 MB/s eta 0:00:00
# ...

# %%
# !pip install pymongo dnspython

# %%
from pymongo import MongoClient

# %%
uri = "mongodb+srv://adrashs901_db_user:t7OoMMfQG2dXriQB@resumecluster.c3aoidq.mongodb.net/?appName=ResumeCluster"

client = MongoClient(uri)

# %%
try:
    client.admin.command("ping")
    print("✅ Connected successfully!")
except Exception as e:
    print(e)
# Out:
# ✅ Connected successfully!

# %%
db = client["resume_screener"]   # this doesn't "create" anything yet - just points to a name

# Define your collections (based on your synopsis's data model, Section 9)
predictions_col = db["predictions"]
resumes_col = db["resumes"]
job_descriptions_col = db["job_descriptions"]

print("Database object created. It will appear in Atlas once you insert data.")
# Out:
# Database object created. It will appear in Atlas once you insert data.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')


df = pd.read_csv("/content/drive/MyDrive/resume_project/resume_jd_ranked_final.csv")
records = df.to_dict(orient="records")

result = predictions_col.insert_many(records)
print(f"Inserted {len(result.inserted_ids)} documents")

# NOW check again - "resume_screener" should appear this time
print(client.list_database_names())
# Out:
# Mounted at /content/drive
# Inserted 3894 documents
# ['resume_screener', 'admin', 'local']

# %%
print(predictions_col.count_documents({}))
print(predictions_col.find_one({"job_position_name": "AI Engineer"}))
# Out:
# 3894
# ...
